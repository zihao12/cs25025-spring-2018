# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
import time

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/xinyuw/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
with open('./wiki-text.txt','r') as f:
    text = [line.split() for line in f]

# %%
len(text[0])
# Out:
# 124301826

# %% [markdown]
# # Data preprocessing

# %%
from collections import Counter
c_text = Counter(text[0])

# %%
min_threshold = 500
#text_filter1 = [k for k, v in c_text.items() if v > min_threshold]
start = time.time()
text_fil1= [word for word in text[0] if not word in stop_words]
text_filtered = [k for k in text_fil1 if c_text[k] > min_threshold]
end = time.time()
print("time elapsed: " + str(end-start))
print(len(set(text_filtered)))
# Out:
# time elapsed: 21.671967029571533
# 13201

# %%
vocab = list(set(text_filtered))

# %%
index = {}
for i in range(len(vocab)):
    index[vocab[i]] = i

# %%
index
# Out:
# {'renewed': 0,
#  'masculine': 1,
#  'culturally': 2,
#  'induce': 3,
#  'township': 4,
#  'gypsy': 5,
#  'angular': 6,
#  'president': 7,
#  'syllable': 8,
#  'eliminated': 9,
#  'march': 10,
#  'turns': 11,
#  'accents': 12,
#  'agnes': 13,
#  'peaceful': 14,
#  'actor': 15,
#  'person': 16,
#  'cookies': 17,
#  'imposed': 18,
#  'te': 19,
#  'op': 20,
#  'alpha': 21,
#  'explain': 22,
#  'rue': 23,
#  'browns': 24,
#  'minimize': 25,
#  'relatively': 26,
#  'compact': 27,
#  'southwestern': 28,
#  'natives': 29,
#  'aug': 30,
#  'mumbai': 31,
#  'count': 32,
#  'positioned': 33,
#  'east': 34,
#  'dana': 35,
#  'treaties': 36,
#  'risen': 37,
#  'kate': 38,
#  'eligible': 39,
#  'inventor': 40,
#  'greenwich': 41,
#  'mercury': 42,
#  'selective': 43,
#  'dinosaurs': 44,
#  'receive': 45,
#  'black': 46,
#  'successors': 47,
#  'underway': 48,
#  'sky': 49,
#  'excluding': 50,
#  'fathers': 51,
#  'spent': 52,
#  'loud': 53,
#  'continents': 54,
#  'brazil': 55,
#  'bel': 56,
#  'paint': 57,
#  'navy': 58,
#  'rectangular': 59,
#  'profiles': 60,
#  'establishment': 61,
#  'orbital': 62,
#  'campaign': 63,
#  'logging': 64,
#  'unesco': 65,
#  'polish': 66,
#  'procession': 67,
#  'fighter': 68,
#  'sustainable': 69,
#  'three': 70,
#  'doubts': 71,
#  'bud': 72,
#  'enthusiastic': 73,
#  'ulrich': 74,
#  'disturbed': 75,
#  'dome': 76,
#  'describe': 77,
#  'configurations': 78,
#  'agreed': 79,
#  'technique': 80,
#  'sites': 81,
#  'ipod': 82,
#  'campaigned': 83,
#  'logically': 84,
#  'projected': 85,
#  'amid': 86,
#  'perceive': 87,
#  'gorbachev': 88,
#  'plea': 89,
#  'loving': 90,
#  'tickets': 91,
#  'meditation': 92,
#  'peru': 93,
#  'movements': 94,
#  'tends': 95,
#  'distribute': 96,
#  'thin': 97,
#  'mongolia': 98,
#  'hellenistic': 99,
#  'happens': 100,
#  'guarded': 101,
#  'iroquois': 102,
#  'volga': 103,
#  'andr': 104,
#  'decreased': 105,
#  'grow': 106,
#  'stripes': 107,
#  'currents': 108,
#  'bavarian': 109,
#  'auckland': 110,
#  'mentally': 111,
#  'boiled': 112,
#  'stars': 113,
#  'cop': 114,
#  'ark': 115,
#  'followed': 116,
#  'underlying': 117,
#  'conversation': 118,
#  'beer': 119,
#  'rafael': 120,
#  'paragraph': 121,
#  'instructor': 122,
#  'proof': 123,
#  'lowland': 124,
#  'via': 125,
#  'pocket': 126,
#  'meter': 127,
#  'dynamic': 128,
#  'deviation': 129,
#  'sentence': 130,
#  'fantasy': 131,
#  'fleeing': 132,
#  'kite': 133,
#  'analysts': 134,
#  'ken': 135,
#  'sports': 136,
#  'elliot': 137,
#  'wellington': 138,
#  'deadly': 139,
#  'notice': 140,
#  'enacted': 141,
#  'cheshire': 142,
#  'findings': 143,
#  'greg': 144,
#  'earthquake': 145,
#  'hindu': 146,
#  'tenure': 147,
#  'unconstitutional': 148,
#  'joke': 149,
#  'earl': 150,
#  'mel': 151,
#  'constitute': 152,
#  'bulgaria': 153,
#  'descended': 154,
#  'ordering': 155,
#  'gaelic': 156,
#  'joel': 157,
#  'negotiated': 158,
#  'formulated': 159,
#  'camille': 160,
#  'yale': 161,
#  'harmonic': 162,
#  'succession': 163,
#  'slight': 164,
#  'marshall': 165,
#  'glider': 166,
#  'commodities': 167,
#  'thousands': 168,
#  'sack': 169,
#  'crop': 170,
#  'practicing': 171,
#  'solomon': 172,
#  'plaque': 173,
#  'heights': 174,
#  'highlighted': 175,
#  'idea': 176,
#  'administrative': 177,
#  'wound': 178,
#  'accomplish': 179,
#  'qaeda': 180,
#  'moses': 181,
#  'willow': 182,
#  'quite': 183,
#  'languages': 184,
#  'nd': 185,
#  'describing': 186,
#  'netherlands': 187,
#  'saved': 188,
#  'denoted': 189,
#  'annie': 190,
#  'mongolian': 191,
#  'deliberately': 192,
#  'appeal': 193,
#  'psalms': 194,
#  'associated': 195,
#  'wood': 196,
#  'intelligence': 197,
#  'distinctive': 198,
#  'cash': 199,
#  'called': 200,
#  'clarendon': 201,
#  'sculptures': 202,
#  'rob': 203,
#  'circumcision': 204,
#  'stronghold': 205,
#  'prone': 206,
#  'issue': 207,
#  'rays': 208,
#  'impaired': 209,
#  'interested': 210,
#  'player': 211,
#  'immune': 212,
#  'greenville': 213,
#  'bahrain': 214,
#  'algebras': 215,
#  'que': 216,
#  'juliet': 217,
#  'enhanced': 218,
#  'vegetable': 219,
#  'adviser': 220,
#  'told': 221,
#  'theologian': 222,
#  'defensive': 223,
#  'proxy': 224,
#  'turtles': 225,
#  'eisenhower': 226,
#  'sights': 227,
#  'locals': 228,
#  'amherst': 229,
#  'master': 230,
#  'defining': 231,
#  'pigs': 232,
#  'newfoundland': 233,
#  'provided': 234,
#  'alchemy': 235,
#  'gaps': 236,
#  'marc': 237,
#  'facts': 238,
#  'martyr': 239,
#  'pilgrims': 240,
#  'hockey': 241,
#  'kent': 242,
#  'actresses': 243,
#  'sans': 244,
#  'create': 245,
#  'televised': 246,
#  'documents': 247,
#  'defect': 248,
#  'escort': 249,
#  'addiction': 250,
#  'brewing': 251,
#  'study': 252,
#  'gnostic': 253,
#  'seventeenth': 254,
#  'nobel': 255,
#  'corridor': 256,
#  'bethlehem': 257,
#  'prize': 258,
#  'rounded': 259,
#  'axioms': 260,
#  'finishing': 261,
#  'newspapers': 262,
#  'abolition': 263,
#  'darkness': 264,
#  'vishnu': 265,
#  'male': 266,
#  'georg': 267,
#  'fir': 268,
#  'airlines': 269,
#  'qur': 270,
#  'indonesia': 271,
#  'classes': 272,
#  'cadillac': 273,
#  'train': 274,
#  'humid': 275,
#  'protect': 276,
#  'marseille': 277,
#  'arch': 278,
#  'maxwell': 279,
#  'reliable': 280,
#  'br': 281,
#  'offer': 282,
#  'allowing': 283,
#  'populations': 284,
#  'austrian': 285,
#  'valves': 286,
#  'shift': 287,
#  'errors': 288,
#  'christian': 289,
#  'organizational': 290,
#  'food': 291,
#  'freeze': 292,
#  'waterways': 293,
#  'incredible': 294,
#  'strongest': 295,
#  'journalism': 296,
#  'pure': 297,
#  'miles': 298,
#  'orwell': 299,
#  'mistakes': 300,
#  'isolated': 301,
#  'benefits': 302,
#  'traveled': 303,
#  'become': 304,
#  'machinery': 305,
#  'visible': 306,
#  'scotland': 307,
#  'jonathan': 308,
#  'remake': 309,
#  'clarke': 310,
#  'poem': 311,
#  'translate': 312,
#  'eccentric': 313,
#  'starred': 314,
#  'regained': 315,
#  'worlds': 316,
#  'keen': 317,
#  'encyclopaedia': 318,
#  'biology': 319,
#  'aid': 320,
#  'collision': 321,
#  'products': 322,
#  'coup': 323,
#  'broke': 324,
#  'acceptance': 325,
#  'microwave': 326,
#  'neglected': 327,
#  'armies': 328,
#  'losses': 329,
#  'buffalo': 330,
#  'pink': 331,
#  'globalization': 332,
#  'bruce': 333,
#  'learning': 334,
#  'merging': 335,
#  'produce': 336,
#  'zero': 337,
#  'comprise': 338,
#  'cooled': 339,
#  'rodgers': 340,
#  'meiji': 341,
#  'carter': 342,
#  'soldier': 343,
#  'industrial': 344,
#  'concerto': 345,
#  'sculptor': 346,
#  'waterfront': 347,
#  'rivers': 348,
#  'flemish': 349,
#  'intellectual': 350,
#  'newer': 351,
#  'symbolism': 352,
#  'enterprise': 353,
#  'vietnamese': 354,
#  'bahamas': 355,
#  'entrance': 356,
#  'sovereign': 357,
#  'typically': 358,
#  'cache': 359,
#  'thebes': 360,
#  'unexpected': 361,
#  'disciples': 362,
#  'rises': 363,
#  'css': 364,
#  'russians': 365,
#  'valve': 366,
#  'mainly': 367,
#  'afb': 368,
#  'exhibition': 369,
#  'scholars': 370,
#  'manhattan': 371,
#  'available': 372,
#  'anatolia': 373,
#  'diesel': 374,
#  'uploads': 375,
#  'feb': 376,
#  'nationals': 377,
#  'rama': 378,
#  'artistic': 379,
#  'explosives': 380,
#  'tarquin': 381,
#  'subdivided': 382,
#  'neutrons': 383,
#  'metric': 384,
#  'cheaper': 385,
#  'result': 386,
#  'respectively': 387,
#  'belts': 388,
#  'honor': 389,
#  'planetary': 390,
#  'modules': 391,
#  'bug': 392,
#  'symmetry': 393,
#  'annals': 394,
#  'whig': 395,
#  'lucrative': 396,
#  'woodstock': 397,
#  'aegean': 398,
#  'possession': 399,
#  'usd': 400,
#  'updates': 401,
#  'dietary': 402,
#  'archie': 403,
#  'calculate': 404,
#  'stephen': 405,
#  'glacier': 406,
#  'proposal': 407,
#  'disaster': 408,
#  'jargon': 409,
#  'ceremony': 410,
#  'avoiding': 411,
#  'cavalry': 412,
#  'watched': 413,
#  'c': 414,
#  'mathematician': 415,
#  'ames': 416,
#  'scenarios': 417,
#  'preserve': 418,
#  'inversion': 419,
#  'wool': 420,
#  'critique': 421,
#  'focuses': 422,
#  'peaked': 423,
#  'ass': 424,
#  'disbanded': 425,
#  'cheese': 426,
#  'later': 427,
#  'phonetic': 428,
#  'der': 429,
#  'liquid': 430,
#  'attachment': 431,
#  'zoo': 432,
#  'paul': 433,
#  'classis': 434,
#  'billed': 435,
#  'dei': 436,
#  'barriers': 437,
#  'bend': 438,
#  'bb': 439,
#  'practitioners': 440,
#  'discharged': 441,
#  'retained': 442,
#  'alex': 443,
#  'cr': 444,
#  'yeltsin': 445,
#  'scott': 446,
#  'monmouth': 447,
#  'illustrator': 448,
#  'portal': 449,
#  'disagreement': 450,
#  'tough': 451,
#  'nietzsche': 452,
#  'innocence': 453,
#  'pike': 454,
#  'arthur': 455,
#  'along': 456,
#  'spoke': 457,
#  'aberdeen': 458,
#  'bronx': 459,
#  'enters': 460,
#  'manifesto': 461,
#  'forth': 462,
#  'recruit': 463,
#  'comedian': 464,
#  'tunisia': 465,
#  'emerald': 466,
#  'orientation': 467,
#  'gifted': 468,
#  'generous': 469,
#  'expresses': 470,
#  'instructions': 471,
#  'gb': 472,
#  'atlantis': 473,
#  'falkland': 474,
#  'concentration': 475,
#  'holland': 476,
#  'gerald': 477,
#  'differed': 478,
#  'legend': 479,
#  'paid': 480,
#  'habitats': 481,
#  'scholarly': 482,
#  'drain': 483,
#  'ruler': 484,
#  'southern': 485,
#  'canary': 486,
#  'protein': 487,
#  'varies': 488,
#  'nt': 489,
#  'promotion': 490,
#  'appearance': 491,
#  'york': 492,
#  'murphy': 493,
#  'clean': 494,
#  'account': 495,
#  'yugoslav': 496,
#  'stripped': 497,
#  'deserted': 498,
#  'tracks': 499,
#  'anarchy': 500,
#  'qualified': 501,
#  'axiom': 502,
#  'notoc': 503,
#  'stream': 504,
#  'jpg': 505,
#  'pa': 506,
#  'neptune': 507,
#  'threatened': 508,
#  'pointed': 509,
#  'damages': 510,
#  'singular': 511,
#  'ml': 512,
#  'colloquial': 513,
#  'internally': 514,
#  'gloucester': 515,
#  'organizations': 516,
#  'lions': 517,
#  'stood': 518,
#  'sets': 519,
#  'religions': 520,
#  'souls': 521,
#  'willis': 522,
#  'rely': 523,
#  'vegetation': 524,
#  'spd': 525,
#  'bounty': 526,
#  'remarkable': 527,
#  'luc': 528,
#  'trumpet': 529,
#  'metre': 530,
#  'bath': 531,
#  'drop': 532,
#  'banks': 533,
#  'transparent': 534,
#  'desktop': 535,
#  'brooks': 536,
#  'start': 537,
#  'tags': 538,
#  'disney': 539,
#  'sparrow': 540,
#  'printing': 541,
#  'competitions': 542,
#  'shots': 543,
#  'leg': 544,
#  'director': 545,
#  'rocks': 546,
#  'fr': 547,
#  'triggered': 548,
#  'branch': 549,
#  'park': 550,
#  'fisheries': 551,
#  'indirectly': 552,
#  'road': 553,
#  'monsters': 554,
#  'holstein': 555,
#  'lacked': 556,
#  'parodied': 557,
#  'anarchism': 558,
#  'roth': 559,
#  'assassination': 560,
#  'holiday': 561,
#  'recommendations': 562,
#  'cp': 563,
#  'participant': 564,
#  'spectators': 565,
#  'procedure': 566,
#  'father': 567,
#  'divide': 568,
#  'burden': 569,
#  'nicholas': 570,
#  'capable': 571,
#  'communal': 572,
#  'conception': 573,
#  'destructive': 574,
#  'somalia': 575,
#  'lens': 576,
#  'destruction': 577,
#  'heathrow': 578,
#  'taken': 579,
#  'identity': 580,
#  'whenever': 581,
#  'malcolm': 582,
#  'comprised': 583,
#  'hanover': 584,
#  'imperialism': 585,
#  'customers': 586,
#  'retrieved': 587,
#  'maple': 588,
#  'mistakenly': 589,
#  'doctoral': 590,
#  'singles': 591,
#  'cretaceous': 592,
#  'measurement': 593,
#  'phillips': 594,
#  'structures': 595,
#  'herman': 596,
#  'compounds': 597,
#  'cheap': 598,
#  'supernatural': 599,
#  'affected': 600,
#  'separates': 601,
#  'explanation': 602,
#  'trinidad': 603,
#  'indirect': 604,
#  'ak': 605,
#  'versions': 606,
#  'endangered': 607,
#  'edmonton': 608,
#  'trent': 609,
#  'armoured': 610,
#  'accomplished': 611,
#  'ck': 612,
#  'weak': 613,
#  'usenet': 614,
#  'websites': 615,
#  'statesman': 616,
#  'stamp': 617,
#  'find': 618,
#  'realizes': 619,
#  'watershed': 620,
#  'psychic': 621,
#  'regina': 622,
#  'pending': 623,
#  'possessions': 624,
#  'airs': 625,
#  'owners': 626,
#  'mutations': 627,
#  'submerged': 628,
#  'disappeared': 629,
#  'historically': 630,
#  'shipping': 631,
#  'issuing': 632,
#  'displayed': 633,
#  'sell': 634,
#  'printed': 635,
#  'death': 636,
#  'apprentice': 637,
#  'barber': 638,
#  'entirety': 639,
#  'tone': 640,
#  'adoption': 641,
#  'secondly': 642,
#  'secret': 643,
#  'clyde': 644,
#  'roland': 645,
#  'ceremonies': 646,
#  'desires': 647,
#  'arm': 648,
#  'continues': 649,
#  'rwanda': 650,
#  'labor': 651,
#  'slaves': 652,
#  'alternate': 653,
#  'goku': 654,
#  'suffolk': 655,
#  'provides': 656,
#  'explorers': 657,
#  'suspected': 658,
#  'flank': 659,
#  'letters': 660,
#  'councils': 661,
#  'armament': 662,
#  'inaugural': 663,
#  'watching': 664,
#  'nutrients': 665,
#  'cdu': 666,
#  'delta': 667,
#  'teen': 668,
#  'incidence': 669,
#  'dimensions': 670,
#  'ball': 671,
#  'g': 672,
#  'decade': 673,
#  'accepting': 674,
#  'brands': 675,
#  'wisdom': 676,
#  'remain': 677,
#  'belongs': 678,
#  'judgment': 679,
#  'crosby': 680,
#  'outlaw': 681,
#  'hrh': 682,
#  'coral': 683,
#  'reserves': 684,
#  'ibid': 685,
#  'pronoun': 686,
#  'lines': 687,
#  'geology': 688,
#  'sermon': 689,
#  'bottles': 690,
#  'eastward': 691,
#  'outlet': 692,
#  'chip': 693,
#  'carlisle': 694,
#  'fix': 695,
#  'vernon': 696,
#  'miniature': 697,
#  'removing': 698,
#  'enduring': 699,
#  'staying': 700,
#  'rhyme': 701,
#  'brooklyn': 702,
#  'done': 703,
#  'details': 704,
#  'presented': 705,
#  'flight': 706,
#  'chinese': 707,
#  'corruption': 708,
#  'flagship': 709,
#  'parrot': 710,
#  'eaton': 711,
#  'fremont': 712,
#  'lynx': 713,
#  'v': 714,
#  'coined': 715,
#  'thomas': 716,
#  'provinces': 717,
#  'bread': 718,
#  'exposition': 719,
#  'vegetables': 720,
#  'subdivisions': 721,
#  'nas': 722,
#  'observing': 723,
#  'knowledge': 724,
#  'side': 725,
#  'classified': 726,
#  'yoga': 727,
#  'scientific': 728,
#  'talent': 729,
#  'significance': 730,
#  'sentenced': 731,
#  'penis': 732,
#  'sen': 733,
#  'includes': 734,
#  'expenses': 735,
#  'probe': 736,
#  'exeter': 737,
#  'cnn': 738,
#  'evacuation': 739,
#  'tiger': 740,
#  'magical': 741,
#  'sirius': 742,
#  'ranged': 743,
#  'jorge': 744,
#  'url': 745,
#  'anterior': 746,
#  'originates': 747,
#  'b': 748,
#  'desk': 749,
#  'icons': 750,
#  'gasoline': 751,
#  'orders': 752,
#  'shoulders': 753,
#  'commit': 754,
#  'commune': 755,
#  'increase': 756,
#  'disappear': 757,
#  'doubled': 758,
#  'hunter': 759,
#  'danny': 760,
#  'steel': 761,
#  'roger': 762,
#  'sanders': 763,
#  'treatment': 764,
#  'charges': 765,
#  'largely': 766,
#  'specifies': 767,
#  'thread': 768,
#  'frankenstein': 769,
#  'rough': 770,
#  'path': 771,
#  'recalled': 772,
#  'etruscan': 773,
#  'often': 774,
#  'map': 775,
#  'madness': 776,
#  'exploited': 777,
#  'cartoonist': 778,
#  'feat': 779,
#  'wonder': 780,
#  'freestyle': 781,
#  'feeding': 782,
#  'demonstrations': 783,
#  'talks': 784,
#  'klan': 785,
#  'bag': 786,
#  'car': 787,
#  'equations': 788,
#  'dame': 789,
#  'five': 790,
#  'philosophers': 791,
#  'lower': 792,
#  'attacking': 793,
#  'colon': 794,
#  'heinz': 795,
#  'mongol': 796,
#  'reorganized': 797,
#  'shark': 798,
#  'certain': 799,
#  'sort': 800,
#  'stakes': 801,
#  'miguel': 802,
#  'embraced': 803,
#  'arsenal': 804,
#  'connotations': 805,
#  'mandatory': 806,
#  'ability': 807,
#  'presley': 808,
#  'proceedings': 809,
#  'gentleman': 810,
#  'zurich': 811,
#  'duet': 812,
#  'sanctuary': 813,
#  'cuisine': 814,
#  'performing': 815,
#  'veteran': 816,
#  'saratoga': 817,
#  'malaysia': 818,
#  'nm': 819,
#  'debate': 820,
#  'dig': 821,
#  'expressway': 822,
#  'soils': 823,
#  'halls': 824,
#  'super': 825,
#  'northwest': 826,
#  'acquire': 827,
#  'girlfriend': 828,
#  'camera': 829,
#  'territories': 830,
#  'ways': 831,
#  'winters': 832,
#  'prevented': 833,
#  'implemented': 834,
#  'cherry': 835,
#  'baron': 836,
#  'endless': 837,
#  'rare': 838,
#  'fry': 839,
#  'quote': 840,
#  'banknotes': 841,
#  'tourists': 842,
#  'prevalence': 843,
#  'beaches': 844,
#  'restored': 845,
#  'ju': 846,
#  'introducing': 847,
#  'commandments': 848,
#  'aims': 849,
#  'dignity': 850,
#  'vacation': 851,
#  'yi': 852,
#  'creative': 853,
#  'wrote': 854,
#  'paperback': 855,
#  'imply': 856,
#  'humidity': 857,
#  'lucas': 858,
#  'ea': 859,
#  'possessed': 860,
#  'justify': 861,
#  'tomorrow': 862,
#  'backs': 863,
#  'cobain': 864,
#  'onwards': 865,
#  'outputs': 866,
#  'equipment': 867,
#  'diffraction': 868,
#  'sitcom': 869,
#  'birmingham': 870,
#  'pearson': 871,
#  'credited': 872,
#  'draw': 873,
#  'click': 874,
#  'compound': 875,
#  'regions': 876,
#  'traveling': 877,
#  'stairs': 878,
#  'boyle': 879,
#  'windows': 880,
#  'little': 881,
#  'middlesex': 882,
#  'team': 883,
#  'reaction': 884,
#  'vegas': 885,
#  'fully': 886,
#  'imagine': 887,
#  'lyon': 888,
#  'spectral': 889,
#  'dealing': 890,
#  'region': 891,
#  'elk': 892,
#  'generations': 893,
#  'hank': 894,
#  'jpeg': 895,
#  'spartan': 896,
#  'luxembourg': 897,
#  'medal': 898,
#  'pdf': 899,
#  'hall': 900,
#  'preface': 901,
#  'edges': 902,
#  'shipbuilding': 903,
#  'housed': 904,
#  'bench': 905,
#  'breathing': 906,
#  'blockade': 907,
#  'affects': 908,
#  'part': 909,
#  'barcelona': 910,
#  'sang': 911,
#  'argentina': 912,
#  'bavaria': 913,
#  'testament': 914,
#  'believe': 915,
#  'designer': 916,
#  'legitimacy': 917,
#  'seem': 918,
#  'kr': 919,
#  'cave': 920,
#  'sounding': 921,
#  'controlling': 922,
#  'nouns': 923,
#  'golden': 924,
#  'dispersed': 925,
#  'credibility': 926,
#  'echo': 927,
#  'emphasizes': 928,
#  'skills': 929,
#  'pins': 930,
#  'installations': 931,
#  'commodore': 932,
#  'infrogmation': 933,
#  'died': 934,
#  'prague': 935,
#  'photon': 936,
#  'volcanoes': 937,
#  'volleyball': 938,
#  'joy': 939,
#  'sympathetic': 940,
#  'donovan': 941,
#  'bacterial': 942,
#  'brothers': 943,
#  'fibre': 944,
#  'vhs': 945,
#  'intermediate': 946,
#  'approval': 947,
#  'crucial': 948,
#  'counties': 949,
#  'commonly': 950,
#  'bonds': 951,
#  'honours': 952,
#  'forced': 953,
#  'ducks': 954,
#  'blows': 955,
#  'sleep': 956,
#  'maximum': 957,
#  'gundam': 958,
#  'papacy': 959,
#  'winter': 960,
#  'articles': 961,
#  'gain': 962,
#  'operates': 963,
#  'comeback': 964,
#  'censorship': 965,
#  'rulers': 966,
#  'tired': 967,
#  'cascade': 968,
#  'predictions': 969,
#  'discovers': 970,
#  'across': 971,
#  'calcutta': 972,
#  'dropped': 973,
#  'growth': 974,
#  'historia': 975,
#  'publishes': 976,
#  'contradictory': 977,
#  'drums': 978,
#  'producer': 979,
#  'susceptible': 980,
#  'deposit': 981,
#  'epic': 982,
#  'cosmos': 983,
#  'declared': 984,
#  'replied': 985,
#  'patriot': 986,
#  'shut': 987,
#  'quo': 988,
#  'warming': 989,
#  'prophet': 990,
#  'elephants': 991,
#  'dissolved': 992,
#  'toward': 993,
#  'presentation': 994,
#  'sir': 995,
#  'child': 996,
#  'artery': 997,
#  'technologies': 998,
#  'practically': 999,
#  ...}

# %% [markdown]
# # PMI Embedding

# %%
text_t = text_filtered[:500]
#vocab_t = set(text_t)

# %% [markdown]
# ## First, create a word count matrix

# %%
s = "to be or not to be"

# %%
import itertools
pairs = list(itertools.permutations(vocab, 2))

# %%
c_pairs = Counter(pairs)

# %%
c_pairs
# Out:
# Counter({('renewed', 'masculine'): 1,
#          ('renewed', 'culturally'): 1,
#          ('renewed', 'induce'): 1,
#          ('renewed', 'township'): 1,
#          ('renewed', 'gypsy'): 1,
#          ('renewed', 'angular'): 1,
#          ('renewed', 'president'): 1,
#          ('renewed', 'syllable'): 1,
#          ('renewed', 'eliminated'): 1,
#          ('renewed', 'march'): 1,
#          ('renewed', 'turns'): 1,
#          ('renewed', 'accents'): 1,
#          ('renewed', 'agnes'): 1,
#          ('renewed', 'peaceful'): 1,
#          ('renewed', 'actor'): 1,
#          ('renewed', 'person'): 1,
#          ('renewed', 'cookies'): 1,
#          ('renewed', 'imposed'): 1,
#          ('renewed', 'te'): 1,
#          ('renewed', 'op'): 1,
#          ('renewed', 'alpha'): 1,
#          ('renewed', 'explain'): 1,
#          ('renewed', 'rue'): 1,
#          ('renewed', 'browns'): 1,
#          ('renewed', 'minimize'): 1,
#          ('renewed', 'relatively'): 1,
#          ('renewed', 'compact'): 1,
#          ('renewed', 'southwestern'): 1,
#          ('renewed', 'natives'): 1,
#          ('renewed', 'aug'): 1,
#          ('renewed', 'mumbai'): 1,
#          ('renewed', 'count'): 1,
#          ('renewed', 'positioned'): 1,
#          ('renewed', 'east'): 1,
#          ('renewed', 'dana'): 1,
#          ('renewed', 'treaties'): 1,
#          ('renewed', 'risen'): 1,
#          ('renewed', 'kate'): 1,
#          ('renewed', 'eligible'): 1,
#          ('renewed', 'inventor'): 1,
#          ('renewed', 'greenwich'): 1,
#          ('renewed', 'mercury'): 1,
#          ('renewed', 'selective'): 1,
#          ('renewed', 'dinosaurs'): 1,
#          ('renewed', 'receive'): 1,
#          ('renewed', 'black'): 1,
#          ('renewed', 'successors'): 1,
#          ('renewed', 'underway'): 1,
#          ('renewed', 'sky'): 1,
#          ('renewed', 'excluding'): 1,
#          ('renewed', 'fathers'): 1,
#          ('renewed', 'spent'): 1,
#          ('renewed', 'loud'): 1,
#          ('renewed', 'continents'): 1,
#          ('renewed', 'brazil'): 1,
#          ('renewed', 'bel'): 1,
#          ('renewed', 'paint'): 1,
#          ('renewed', 'navy'): 1,
#          ('renewed', 'rectangular'): 1,
#          ('renewed', 'profiles'): 1,
#          ('renewed', 'establishment'): 1,
#          ('renewed', 'orbital'): 1,
#          ('renewed', 'campaign'): 1,
#          ('renewed', 'logging'): 1,
#          ('renewed', 'unesco'): 1,
#          ('renewed', 'polish'): 1,
#          ('renewed', 'procession'): 1,
#          ('renewed', 'fighter'): 1,
#          ('renewed', 'sustainable'): 1,
#          ('renewed', 'three'): 1,
#          ('renewed', 'doubts'): 1,
#          ('renewed', 'bud'): 1,
#          ('renewed', 'enthusiastic'): 1,
#          ('renewed', 'ulrich'): 1,
#          ('renewed', 'disturbed'): 1,
#          ('renewed', 'dome'): 1,
#          ('renewed', 'describe'): 1,
#          ('renewed', 'configurations'): 1,
#          ('renewed', 'agreed'): 1,
#          ('renewed', 'technique'): 1,
#          ('renewed', 'sites'): 1,
#          ('renewed', 'ipod'): 1,
#          ('renewed', 'campaigned'): 1,
#          ('renewed', 'logically'): 1,
#          ('renewed', 'projected'): 1,
#          ('renewed', 'amid'): 1,
#          ('renewed', 'perceive'): 1,
#          ('renewed', 'gorbachev'): 1,
#          ('renewed', 'plea'): 1,
#          ('renewed', 'loving'): 1,
#          ('renewed', 'tickets'): 1,
#          ('renewed', 'meditation'): 1,
#          ('renewed', 'peru'): 1,
#          ('renewed', 'movements'): 1,
#          ('renewed', 'tends'): 1,
#          ('renewed', 'distribute'): 1,
#          ('renewed', 'thin'): 1,
#          ('renewed', 'mongolia'): 1,
#          ('renewed', 'hellenistic'): 1,
#          ('renewed', 'happens'): 1,
#          ('renewed', 'guarded'): 1,
#          ('renewed', 'iroquois'): 1,
#          ('renewed', 'volga'): 1,
#          ('renewed', 'andr'): 1,
#          ('renewed', 'decreased'): 1,
#          ('renewed', 'grow'): 1,
#          ('renewed', 'stripes'): 1,
#          ('renewed', 'currents'): 1,
#          ('renewed', 'bavarian'): 1,
#          ('renewed', 'auckland'): 1,
#          ('renewed', 'mentally'): 1,
#          ('renewed', 'boiled'): 1,
#          ('renewed', 'stars'): 1,
#          ('renewed', 'cop'): 1,
#          ('renewed', 'ark'): 1,
#          ('renewed', 'followed'): 1,
#          ('renewed', 'underlying'): 1,
#          ('renewed', 'conversation'): 1,
#          ('renewed', 'beer'): 1,
#          ('renewed', 'rafael'): 1,
#          ('renewed', 'paragraph'): 1,
#          ('renewed', 'instructor'): 1,
#          ('renewed', 'proof'): 1,
#          ('renewed', 'lowland'): 1,
#          ('renewed', 'via'): 1,
#          ('renewed', 'pocket'): 1,
#          ('renewed', 'meter'): 1,
#          ('renewed', 'dynamic'): 1,
#          ('renewed', 'deviation'): 1,
#          ('renewed', 'sentence'): 1,
#          ('renewed', 'fantasy'): 1,
#          ('renewed', 'fleeing'): 1,
#          ('renewed', 'kite'): 1,
#          ('renewed', 'analysts'): 1,
#          ('renewed', 'ken'): 1,
#          ('renewed', 'sports'): 1,
#          ('renewed', 'elliot'): 1,
#          ('renewed', 'wellington'): 1,
#          ('renewed', 'deadly'): 1,
#          ('renewed', 'notice'): 1,
#          ('renewed', 'enacted'): 1,
#          ('renewed', 'cheshire'): 1,
#          ('renewed', 'findings'): 1,
#          ('renewed', 'greg'): 1,
#          ('renewed', 'earthquake'): 1,
#          ('renewed', 'hindu'): 1,
#          ('renewed', 'tenure'): 1,
#          ('renewed', 'unconstitutional'): 1,
#          ('renewed', 'joke'): 1,
#          ('renewed', 'earl'): 1,
#          ('renewed', 'mel'): 1,
#          ('renewed', 'constitute'): 1,
#          ('renewed', 'bulgaria'): 1,
#          ('renewed', 'descended'): 1,
#          ('renewed', 'ordering'): 1,
#          ('renewed', 'gaelic'): 1,
#          ('renewed', 'joel'): 1,
#          ('renewed', 'negotiated'): 1,
#          ('renewed', 'formulated'): 1,
#          ('renewed', 'camille'): 1,
#          ('renewed', 'yale'): 1,
#          ('renewed', 'harmonic'): 1,
#          ('renewed', 'succession'): 1,
#          ('renewed', 'slight'): 1,
#          ('renewed', 'marshall'): 1,
#          ('renewed', 'glider'): 1,
#          ('renewed', 'commodities'): 1,
#          ('renewed', 'thousands'): 1,
#          ('renewed', 'sack'): 1,
#          ('renewed', 'crop'): 1,
#          ('renewed', 'practicing'): 1,
#          ('renewed', 'solomon'): 1,
#          ('renewed', 'plaque'): 1,
#          ('renewed', 'heights'): 1,
#          ('renewed', 'highlighted'): 1,
#          ('renewed', 'idea'): 1,
#          ('renewed', 'administrative'): 1,
#          ('renewed', 'wound'): 1,
#          ('renewed', 'accomplish'): 1,
#          ('renewed', 'qaeda'): 1,
#          ('renewed', 'moses'): 1,
#          ('renewed', 'willow'): 1,
#          ('renewed', 'quite'): 1,
#          ('renewed', 'languages'): 1,
#          ('renewed', 'nd'): 1,
#          ('renewed', 'describing'): 1,
#          ('renewed', 'netherlands'): 1,
#          ('renewed', 'saved'): 1,
#          ('renewed', 'denoted'): 1,
#          ('renewed', 'annie'): 1,
#          ('renewed', 'mongolian'): 1,
#          ('renewed', 'deliberately'): 1,
#          ('renewed', 'appeal'): 1,
#          ('renewed', 'psalms'): 1,
#          ('renewed', 'associated'): 1,
#          ('renewed', 'wood'): 1,
#          ('renewed', 'intelligence'): 1,
#          ('renewed', 'distinctive'): 1,
#          ('renewed', 'cash'): 1,
#          ('renewed', 'called'): 1,
#          ('renewed', 'clarendon'): 1,
#          ('renewed', 'sculptures'): 1,
#          ('renewed', 'rob'): 1,
#          ('renewed', 'circumcision'): 1,
#          ('renewed', 'stronghold'): 1,
#          ('renewed', 'prone'): 1,
#          ('renewed', 'issue'): 1,
#          ('renewed', 'rays'): 1,
#          ('renewed', 'impaired'): 1,
#          ('renewed', 'interested'): 1,
#          ('renewed', 'player'): 1,
#          ('renewed', 'immune'): 1,
#          ('renewed', 'greenville'): 1,
#          ('renewed', 'bahrain'): 1,
#          ('renewed', 'algebras'): 1,
#          ('renewed', 'que'): 1,
#          ('renewed', 'juliet'): 1,
#          ('renewed', 'enhanced'): 1,
#          ('renewed', 'vegetable'): 1,
#          ('renewed', 'adviser'): 1,
#          ('renewed', 'told'): 1,
#          ('renewed', 'theologian'): 1,
#          ('renewed', 'defensive'): 1,
#          ('renewed', 'proxy'): 1,
#          ('renewed', 'turtles'): 1,
#          ('renewed', 'eisenhower'): 1,
#          ('renewed', 'sights'): 1,
#          ('renewed', 'locals'): 1,
#          ('renewed', 'amherst'): 1,
#          ('renewed', 'master'): 1,
#          ('renewed', 'defining'): 1,
#          ('renewed', 'pigs'): 1,
#          ('renewed', 'newfoundland'): 1,
#          ('renewed', 'provided'): 1,
#          ('renewed', 'alchemy'): 1,
#          ('renewed', 'gaps'): 1,
#          ('renewed', 'marc'): 1,
#          ('renewed', 'facts'): 1,
#          ('renewed', 'martyr'): 1,
#          ('renewed', 'pilgrims'): 1,
#          ('renewed', 'hockey'): 1,
#          ('renewed', 'kent'): 1,
#          ('renewed', 'actresses'): 1,
#          ('renewed', 'sans'): 1,
#          ('renewed', 'create'): 1,
#          ('renewed', 'televised'): 1,
#          ('renewed', 'documents'): 1,
#          ('renewed', 'defect'): 1,
#          ('renewed', 'escort'): 1,
#          ('renewed', 'addiction'): 1,
#          ('renewed', 'brewing'): 1,
#          ('renewed', 'study'): 1,
#          ('renewed', 'gnostic'): 1,
#          ('renewed', 'seventeenth'): 1,
#          ('renewed', 'nobel'): 1,
#          ('renewed', 'corridor'): 1,
#          ('renewed', 'bethlehem'): 1,
#          ('renewed', 'prize'): 1,
#          ('renewed', 'rounded'): 1,
#          ('renewed', 'axioms'): 1,
#          ('renewed', 'finishing'): 1,
#          ('renewed', 'newspapers'): 1,
#          ('renewed', 'abolition'): 1,
#          ('renewed', 'darkness'): 1,
#          ('renewed', 'vishnu'): 1,
#          ('renewed', 'male'): 1,
#          ('renewed', 'georg'): 1,
#          ('renewed', 'fir'): 1,
#          ('renewed', 'airlines'): 1,
#          ('renewed', 'qur'): 1,
#          ('renewed', 'indonesia'): 1,
#          ('renewed', 'classes'): 1,
#          ('renewed', 'cadillac'): 1,
#          ('renewed', 'train'): 1,
#          ('renewed', 'humid'): 1,
#          ('renewed', 'protect'): 1,
#          ('renewed', 'marseille'): 1,
#          ('renewed', 'arch'): 1,
#          ('renewed', 'maxwell'): 1,
#          ('renewed', 'reliable'): 1,
#          ('renewed', 'br'): 1,
#          ('renewed', 'offer'): 1,
#          ('renewed', 'allowing'): 1,
#          ('renewed', 'populations'): 1,
#          ('renewed', 'austrian'): 1,
#          ('renewed', 'valves'): 1,
#          ('renewed', 'shift'): 1,
#          ('renewed', 'errors'): 1,
#          ('renewed', 'christian'): 1,
#          ('renewed', 'organizational'): 1,
#          ('renewed', 'food'): 1,
#          ('renewed', 'freeze'): 1,
#          ('renewed', 'waterways'): 1,
#          ('renewed', 'incredible'): 1,
#          ('renewed', 'strongest'): 1,
#          ('renewed', 'journalism'): 1,
#          ('renewed', 'pure'): 1,
#          ('renewed', 'miles'): 1,
#          ('renewed', 'orwell'): 1,
#          ('renewed', 'mistakes'): 1,
#          ('renewed', 'isolated'): 1,
#          ('renewed', 'benefits'): 1,
#          ('renewed', 'traveled'): 1,
#          ('renewed', 'become'): 1,
#          ('renewed', 'machinery'): 1,
#          ('renewed', 'visible'): 1,
#          ('renewed', 'scotland'): 1,
#          ('renewed', 'jonathan'): 1,
#          ('renewed', 'remake'): 1,
#          ('renewed', 'clarke'): 1,
#          ('renewed', 'poem'): 1,
#          ('renewed', 'translate'): 1,
#          ('renewed', 'eccentric'): 1,
#          ('renewed', 'starred'): 1,
#          ('renewed', 'regained'): 1,
#          ('renewed', 'worlds'): 1,
#          ('renewed', 'keen'): 1,
#          ('renewed', 'encyclopaedia'): 1,
#          ('renewed', 'biology'): 1,
#          ('renewed', 'aid'): 1,
#          ('renewed', 'collision'): 1,
#          ('renewed', 'products'): 1,
#          ('renewed', 'coup'): 1,
#          ('renewed', 'broke'): 1,
#          ('renewed', 'acceptance'): 1,
#          ('renewed', 'microwave'): 1,
#          ('renewed', 'neglected'): 1,
#          ('renewed', 'armies'): 1,
#          ('renewed', 'losses'): 1,
#          ('renewed', 'buffalo'): 1,
#          ('renewed', 'pink'): 1,
#          ('renewed', 'globalization'): 1,
#          ('renewed', 'bruce'): 1,
#          ('renewed', 'learning'): 1,
#          ('renewed', 'merging'): 1,
#          ('renewed', 'produce'): 1,
#          ('renewed', 'zero'): 1,
#          ('renewed', 'comprise'): 1,
#          ('renewed', 'cooled'): 1,
#          ('renewed', 'rodgers'): 1,
#          ('renewed', 'meiji'): 1,
#          ('renewed', 'carter'): 1,
#          ('renewed', 'soldier'): 1,
#          ('renewed', 'industrial'): 1,
#          ('renewed', 'concerto'): 1,
#          ('renewed', 'sculptor'): 1,
#          ('renewed', 'waterfront'): 1,
#          ('renewed', 'rivers'): 1,
#          ('renewed', 'flemish'): 1,
#          ('renewed', 'intellectual'): 1,
#          ('renewed', 'newer'): 1,
#          ('renewed', 'symbolism'): 1,
#          ('renewed', 'enterprise'): 1,
#          ('renewed', 'vietnamese'): 1,
#          ('renewed', 'bahamas'): 1,
#          ('renewed', 'entrance'): 1,
#          ('renewed', 'sovereign'): 1,
#          ('renewed', 'typically'): 1,
#          ('renewed', 'cache'): 1,
#          ('renewed', 'thebes'): 1,
#          ('renewed', 'unexpected'): 1,
#          ('renewed', 'disciples'): 1,
#          ('renewed', 'rises'): 1,
#          ('renewed', 'css'): 1,
#          ('renewed', 'russians'): 1,
#          ('renewed', 'valve'): 1,
#          ('renewed', 'mainly'): 1,
#          ('renewed', 'afb'): 1,
#          ('renewed', 'exhibition'): 1,
#          ('renewed', 'scholars'): 1,
#          ('renewed', 'manhattan'): 1,
#          ('renewed', 'available'): 1,
#          ('renewed', 'anatolia'): 1,
#          ('renewed', 'diesel'): 1,
#          ('renewed', 'uploads'): 1,
#          ('renewed', 'feb'): 1,
#          ('renewed', 'nationals'): 1,
#          ('renewed', 'rama'): 1,
#          ('renewed', 'artistic'): 1,
#          ('renewed', 'explosives'): 1,
#          ('renewed', 'tarquin'): 1,
#          ('renewed', 'subdivided'): 1,
#          ('renewed', 'neutrons'): 1,
#          ('renewed', 'metric'): 1,
#          ('renewed', 'cheaper'): 1,
#          ('renewed', 'result'): 1,
#          ('renewed', 'respectively'): 1,
#          ('renewed', 'belts'): 1,
#          ('renewed', 'honor'): 1,
#          ('renewed', 'planetary'): 1,
#          ('renewed', 'modules'): 1,
#          ('renewed', 'bug'): 1,
#          ('renewed', 'symmetry'): 1,
#          ('renewed', 'annals'): 1,
#          ('renewed', 'whig'): 1,
#          ('renewed', 'lucrative'): 1,
#          ('renewed', 'woodstock'): 1,
#          ('renewed', 'aegean'): 1,
#          ('renewed', 'possession'): 1,
#          ('renewed', 'usd'): 1,
#          ('renewed', 'updates'): 1,
#          ('renewed', 'dietary'): 1,
#          ('renewed', 'archie'): 1,
#          ('renewed', 'calculate'): 1,
#          ('renewed', 'stephen'): 1,
#          ('renewed', 'glacier'): 1,
#          ('renewed', 'proposal'): 1,
#          ('renewed', 'disaster'): 1,
#          ('renewed', 'jargon'): 1,
#          ('renewed', 'ceremony'): 1,
#          ('renewed', 'avoiding'): 1,
#          ('renewed', 'cavalry'): 1,
#          ('renewed', 'watched'): 1,
#          ('renewed', 'c'): 1,
#          ('renewed', 'mathematician'): 1,
#          ('renewed', 'ames'): 1,
#          ('renewed', 'scenarios'): 1,
#          ('renewed', 'preserve'): 1,
#          ('renewed', 'inversion'): 1,
#          ('renewed', 'wool'): 1,
#          ('renewed', 'critique'): 1,
#          ('renewed', 'focuses'): 1,
#          ('renewed', 'peaked'): 1,
#          ('renewed', 'ass'): 1,
#          ('renewed', 'disbanded'): 1,
#          ('renewed', 'cheese'): 1,
#          ('renewed', 'later'): 1,
#          ('renewed', 'phonetic'): 1,
#          ('renewed', 'der'): 1,
#          ('renewed', 'liquid'): 1,
#          ('renewed', 'attachment'): 1,
#          ('renewed', 'zoo'): 1,
#          ('renewed', 'paul'): 1,
#          ('renewed', 'classis'): 1,
#          ('renewed', 'billed'): 1,
#          ('renewed', 'dei'): 1,
#          ('renewed', 'barriers'): 1,
#          ('renewed', 'bend'): 1,
#          ('renewed', 'bb'): 1,
#          ('renewed', 'practitioners'): 1,
#          ('renewed', 'discharged'): 1,
#          ('renewed', 'retained'): 1,
#          ('renewed', 'alex'): 1,
#          ('renewed', 'cr'): 1,
#          ('renewed', 'yeltsin'): 1,
#          ('renewed', 'scott'): 1,
#          ('renewed', 'monmouth'): 1,
#          ('renewed', 'illustrator'): 1,
#          ('renewed', 'portal'): 1,
#          ('renewed', 'disagreement'): 1,
#          ('renewed', 'tough'): 1,
#          ('renewed', 'nietzsche'): 1,
#          ('renewed', 'innocence'): 1,
#          ('renewed', 'pike'): 1,
#          ('renewed', 'arthur'): 1,
#          ('renewed', 'along'): 1,
#          ('renewed', 'spoke'): 1,
#          ('renewed', 'aberdeen'): 1,
#          ('renewed', 'bronx'): 1,
#          ('renewed', 'enters'): 1,
#          ('renewed', 'manifesto'): 1,
#          ('renewed', 'forth'): 1,
#          ('renewed', 'recruit'): 1,
#          ('renewed', 'comedian'): 1,
#          ('renewed', 'tunisia'): 1,
#          ('renewed', 'emerald'): 1,
#          ('renewed', 'orientation'): 1,
#          ('renewed', 'gifted'): 1,
#          ('renewed', 'generous'): 1,
#          ('renewed', 'expresses'): 1,
#          ('renewed', 'instructions'): 1,
#          ('renewed', 'gb'): 1,
#          ('renewed', 'atlantis'): 1,
#          ('renewed', 'falkland'): 1,
#          ('renewed', 'concentration'): 1,
#          ('renewed', 'holland'): 1,
#          ('renewed', 'gerald'): 1,
#          ('renewed', 'differed'): 1,
#          ('renewed', 'legend'): 1,
#          ('renewed', 'paid'): 1,
#          ('renewed', 'habitats'): 1,
#          ('renewed', 'scholarly'): 1,
#          ('renewed', 'drain'): 1,
#          ('renewed', 'ruler'): 1,
#          ('renewed', 'southern'): 1,
#          ('renewed', 'canary'): 1,
#          ('renewed', 'protein'): 1,
#          ('renewed', 'varies'): 1,
#          ('renewed', 'nt'): 1,
#          ('renewed', 'promotion'): 1,
#          ('renewed', 'appearance'): 1,
#          ('renewed', 'york'): 1,
#          ('renewed', 'murphy'): 1,
#          ('renewed', 'clean'): 1,
#          ('renewed', 'account'): 1,
#          ('renewed', 'yugoslav'): 1,
#          ('renewed', 'stripped'): 1,
#          ('renewed', 'deserted'): 1,
#          ('renewed', 'tracks'): 1,
#          ('renewed', 'anarchy'): 1,
#          ('renewed', 'qualified'): 1,
#          ('renewed', 'axiom'): 1,
#          ('renewed', 'notoc'): 1,
#          ('renewed', 'stream'): 1,
#          ('renewed', 'jpg'): 1,
#          ('renewed', 'pa'): 1,
#          ('renewed', 'neptune'): 1,
#          ('renewed', 'threatened'): 1,
#          ('renewed', 'pointed'): 1,
#          ('renewed', 'damages'): 1,
#          ('renewed', 'singular'): 1,
#          ('renewed', 'ml'): 1,
#          ('renewed', 'colloquial'): 1,
#          ('renewed', 'internally'): 1,
#          ('renewed', 'gloucester'): 1,
#          ('renewed', 'organizations'): 1,
#          ('renewed', 'lions'): 1,
#          ('renewed', 'stood'): 1,
#          ('renewed', 'sets'): 1,
#          ('renewed', 'religions'): 1,
#          ('renewed', 'souls'): 1,
#          ('renewed', 'willis'): 1,
#          ('renewed', 'rely'): 1,
#          ('renewed', 'vegetation'): 1,
#          ('renewed', 'spd'): 1,
#          ('renewed', 'bounty'): 1,
#          ('renewed', 'remarkable'): 1,
#          ('renewed', 'luc'): 1,
#          ('renewed', 'trumpet'): 1,
#          ('renewed', 'metre'): 1,
#          ('renewed', 'bath'): 1,
#          ('renewed', 'drop'): 1,
#          ('renewed', 'banks'): 1,
#          ('renewed', 'transparent'): 1,
#          ('renewed', 'desktop'): 1,
#          ('renewed', 'brooks'): 1,
#          ('renewed', 'start'): 1,
#          ('renewed', 'tags'): 1,
#          ('renewed', 'disney'): 1,
#          ('renewed', 'sparrow'): 1,
#          ('renewed', 'printing'): 1,
#          ('renewed', 'competitions'): 1,
#          ('renewed', 'shots'): 1,
#          ('renewed', 'leg'): 1,
#          ('renewed', 'director'): 1,
#          ('renewed', 'rocks'): 1,
#          ('renewed', 'fr'): 1,
#          ('renewed', 'triggered'): 1,
#          ('renewed', 'branch'): 1,
#          ('renewed', 'park'): 1,
#          ('renewed', 'fisheries'): 1,
#          ('renewed', 'indirectly'): 1,
#          ('renewed', 'road'): 1,
#          ('renewed', 'monsters'): 1,
#          ('renewed', 'holstein'): 1,
#          ('renewed', 'lacked'): 1,
#          ('renewed', 'parodied'): 1,
#          ('renewed', 'anarchism'): 1,
#          ('renewed', 'roth'): 1,
#          ('renewed', 'assassination'): 1,
#          ('renewed', 'holiday'): 1,
#          ('renewed', 'recommendations'): 1,
#          ('renewed', 'cp'): 1,
#          ('renewed', 'participant'): 1,
#          ('renewed', 'spectators'): 1,
#          ('renewed', 'procedure'): 1,
#          ('renewed', 'father'): 1,
#          ('renewed', 'divide'): 1,
#          ('renewed', 'burden'): 1,
#          ('renewed', 'nicholas'): 1,
#          ('renewed', 'capable'): 1,
#          ('renewed', 'communal'): 1,
#          ('renewed', 'conception'): 1,
#          ('renewed', 'destructive'): 1,
#          ('renewed', 'somalia'): 1,
#          ('renewed', 'lens'): 1,
#          ('renewed', 'destruction'): 1,
#          ('renewed', 'heathrow'): 1,
#          ('renewed', 'taken'): 1,
#          ('renewed', 'identity'): 1,
#          ('renewed', 'whenever'): 1,
#          ('renewed', 'malcolm'): 1,
#          ('renewed', 'comprised'): 1,
#          ('renewed', 'hanover'): 1,
#          ('renewed', 'imperialism'): 1,
#          ('renewed', 'customers'): 1,
#          ('renewed', 'retrieved'): 1,
#          ('renewed', 'maple'): 1,
#          ('renewed', 'mistakenly'): 1,
#          ('renewed', 'doctoral'): 1,
#          ('renewed', 'singles'): 1,
#          ('renewed', 'cretaceous'): 1,
#          ('renewed', 'measurement'): 1,
#          ('renewed', 'phillips'): 1,
#          ('renewed', 'structures'): 1,
#          ('renewed', 'herman'): 1,
#          ('renewed', 'compounds'): 1,
#          ('renewed', 'cheap'): 1,
#          ('renewed', 'supernatural'): 1,
#          ('renewed', 'affected'): 1,
#          ('renewed', 'separates'): 1,
#          ('renewed', 'explanation'): 1,
#          ('renewed', 'trinidad'): 1,
#          ('renewed', 'indirect'): 1,
#          ('renewed', 'ak'): 1,
#          ('renewed', 'versions'): 1,
#          ('renewed', 'endangered'): 1,
#          ('renewed', 'edmonton'): 1,
#          ('renewed', 'trent'): 1,
#          ('renewed', 'armoured'): 1,
#          ('renewed', 'accomplished'): 1,
#          ('renewed', 'ck'): 1,
#          ('renewed', 'weak'): 1,
#          ('renewed', 'usenet'): 1,
#          ('renewed', 'websites'): 1,
#          ('renewed', 'statesman'): 1,
#          ('renewed', 'stamp'): 1,
#          ('renewed', 'find'): 1,
#          ('renewed', 'realizes'): 1,
#          ('renewed', 'watershed'): 1,
#          ('renewed', 'psychic'): 1,
#          ('renewed', 'regina'): 1,
#          ('renewed', 'pending'): 1,
#          ('renewed', 'possessions'): 1,
#          ('renewed', 'airs'): 1,
#          ('renewed', 'owners'): 1,
#          ('renewed', 'mutations'): 1,
#          ('renewed', 'submerged'): 1,
#          ('renewed', 'disappeared'): 1,
#          ('renewed', 'historically'): 1,
#          ('renewed', 'shipping'): 1,
#          ('renewed', 'issuing'): 1,
#          ('renewed', 'displayed'): 1,
#          ('renewed', 'sell'): 1,
#          ('renewed', 'printed'): 1,
#          ('renewed', 'death'): 1,
#          ('renewed', 'apprentice'): 1,
#          ('renewed', 'barber'): 1,
#          ('renewed', 'entirety'): 1,
#          ('renewed', 'tone'): 1,
#          ('renewed', 'adoption'): 1,
#          ('renewed', 'secondly'): 1,
#          ('renewed', 'secret'): 1,
#          ('renewed', 'clyde'): 1,
#          ('renewed', 'roland'): 1,
#          ('renewed', 'ceremonies'): 1,
#          ('renewed', 'desires'): 1,
#          ('renewed', 'arm'): 1,
#          ('renewed', 'continues'): 1,
#          ('renewed', 'rwanda'): 1,
#          ('renewed', 'labor'): 1,
#          ('renewed', 'slaves'): 1,
#          ('renewed', 'alternate'): 1,
#          ('renewed', 'goku'): 1,
#          ('renewed', 'suffolk'): 1,
#          ('renewed', 'provides'): 1,
#          ('renewed', 'explorers'): 1,
#          ('renewed', 'suspected'): 1,
#          ('renewed', 'flank'): 1,
#          ('renewed', 'letters'): 1,
#          ('renewed', 'councils'): 1,
#          ('renewed', 'armament'): 1,
#          ('renewed', 'inaugural'): 1,
#          ('renewed', 'watching'): 1,
#          ('renewed', 'nutrients'): 1,
#          ('renewed', 'cdu'): 1,
#          ('renewed', 'delta'): 1,
#          ('renewed', 'teen'): 1,
#          ('renewed', 'incidence'): 1,
#          ('renewed', 'dimensions'): 1,
#          ('renewed', 'ball'): 1,
#          ('renewed', 'g'): 1,
#          ('renewed', 'decade'): 1,
#          ('renewed', 'accepting'): 1,
#          ('renewed', 'brands'): 1,
#          ('renewed', 'wisdom'): 1,
#          ('renewed', 'remain'): 1,
#          ('renewed', 'belongs'): 1,
#          ('renewed', 'judgment'): 1,
#          ('renewed', 'crosby'): 1,
#          ('renewed', 'outlaw'): 1,
#          ('renewed', 'hrh'): 1,
#          ('renewed', 'coral'): 1,
#          ('renewed', 'reserves'): 1,
#          ('renewed', 'ibid'): 1,
#          ('renewed', 'pronoun'): 1,
#          ('renewed', 'lines'): 1,
#          ('renewed', 'geology'): 1,
#          ('renewed', 'sermon'): 1,
#          ('renewed', 'bottles'): 1,
#          ('renewed', 'eastward'): 1,
#          ('renewed', 'outlet'): 1,
#          ('renewed', 'chip'): 1,
#          ('renewed', 'carlisle'): 1,
#          ('renewed', 'fix'): 1,
#          ('renewed', 'vernon'): 1,
#          ('renewed', 'miniature'): 1,
#          ('renewed', 'removing'): 1,
#          ('renewed', 'enduring'): 1,
#          ('renewed', 'staying'): 1,
#          ('renewed', 'rhyme'): 1,
#          ('renewed', 'brooklyn'): 1,
#          ('renewed', 'done'): 1,
#          ('renewed', 'details'): 1,
#          ('renewed', 'presented'): 1,
#          ('renewed', 'flight'): 1,
#          ('renewed', 'chinese'): 1,
#          ('renewed', 'corruption'): 1,
#          ('renewed', 'flagship'): 1,
#          ('renewed', 'parrot'): 1,
#          ('renewed', 'eaton'): 1,
#          ('renewed', 'fremont'): 1,
#          ('renewed', 'lynx'): 1,
#          ('renewed', 'v'): 1,
#          ('renewed', 'coined'): 1,
#          ('renewed', 'thomas'): 1,
#          ('renewed', 'provinces'): 1,
#          ('renewed', 'bread'): 1,
#          ('renewed', 'exposition'): 1,
#          ('renewed', 'vegetables'): 1,
#          ('renewed', 'subdivisions'): 1,
#          ('renewed', 'nas'): 1,
#          ('renewed', 'observing'): 1,
#          ('renewed', 'knowledge'): 1,
#          ('renewed', 'side'): 1,
#          ('renewed', 'classified'): 1,
#          ('renewed', 'yoga'): 1,
#          ('renewed', 'scientific'): 1,
#          ('renewed', 'talent'): 1,
#          ('renewed', 'significance'): 1,
#          ('renewed', 'sentenced'): 1,
#          ('renewed', 'penis'): 1,
#          ('renewed', 'sen'): 1,
#          ('renewed', 'includes'): 1,
#          ('renewed', 'expenses'): 1,
#          ('renewed', 'probe'): 1,
#          ('renewed', 'exeter'): 1,
#          ('renewed', 'cnn'): 1,
#          ('renewed', 'evacuation'): 1,
#          ('renewed', 'tiger'): 1,
#          ('renewed', 'magical'): 1,
#          ('renewed', 'sirius'): 1,
#          ('renewed', 'ranged'): 1,
#          ('renewed', 'jorge'): 1,
#          ('renewed', 'url'): 1,
#          ('renewed', 'anterior'): 1,
#          ('renewed', 'originates'): 1,
#          ('renewed', 'b'): 1,
#          ('renewed', 'desk'): 1,
#          ('renewed', 'icons'): 1,
#          ('renewed', 'gasoline'): 1,
#          ('renewed', 'orders'): 1,
#          ('renewed', 'shoulders'): 1,
#          ('renewed', 'commit'): 1,
#          ('renewed', 'commune'): 1,
#          ('renewed', 'increase'): 1,
#          ('renewed', 'disappear'): 1,
#          ('renewed', 'doubled'): 1,
#          ('renewed', 'hunter'): 1,
#          ('renewed', 'danny'): 1,
#          ('renewed', 'steel'): 1,
#          ('renewed', 'roger'): 1,
#          ('renewed', 'sanders'): 1,
#          ('renewed', 'treatment'): 1,
#          ('renewed', 'charges'): 1,
#          ('renewed', 'largely'): 1,
#          ('renewed', 'specifies'): 1,
#          ('renewed', 'thread'): 1,
#          ('renewed', 'frankenstein'): 1,
#          ('renewed', 'rough'): 1,
#          ('renewed', 'path'): 1,
#          ('renewed', 'recalled'): 1,
#          ('renewed', 'etruscan'): 1,
#          ('renewed', 'often'): 1,
#          ('renewed', 'map'): 1,
#          ('renewed', 'madness'): 1,
#          ('renewed', 'exploited'): 1,
#          ('renewed', 'cartoonist'): 1,
#          ('renewed', 'feat'): 1,
#          ('renewed', 'wonder'): 1,
#          ('renewed', 'freestyle'): 1,
#          ('renewed', 'feeding'): 1,
#          ('renewed', 'demonstrations'): 1,
#          ('renewed', 'talks'): 1,
#          ('renewed', 'klan'): 1,
#          ('renewed', 'bag'): 1,
#          ('renewed', 'car'): 1,
#          ('renewed', 'equations'): 1,
#          ('renewed', 'dame'): 1,
#          ('renewed', 'five'): 1,
#          ('renewed', 'philosophers'): 1,
#          ('renewed', 'lower'): 1,
#          ('renewed', 'attacking'): 1,
#          ('renewed', 'colon'): 1,
#          ('renewed', 'heinz'): 1,
#          ('renewed', 'mongol'): 1,
#          ('renewed', 'reorganized'): 1,
#          ('renewed', 'shark'): 1,
#          ('renewed', 'certain'): 1,
#          ('renewed', 'sort'): 1,
#          ('renewed', 'stakes'): 1,
#          ('renewed', 'miguel'): 1,
#          ('renewed', 'embraced'): 1,
#          ('renewed', 'arsenal'): 1,
#          ('renewed', 'connotations'): 1,
#          ('renewed', 'mandatory'): 1,
#          ('renewed', 'ability'): 1,
#          ('renewed', 'presley'): 1,
#          ('renewed', 'proceedings'): 1,
#          ('renewed', 'gentleman'): 1,
#          ('renewed', 'zurich'): 1,
#          ('renewed', 'duet'): 1,
#          ('renewed', 'sanctuary'): 1,
#          ('renewed', 'cuisine'): 1,
#          ('renewed', 'performing'): 1,
#          ('renewed', 'veteran'): 1,
#          ('renewed', 'saratoga'): 1,
#          ('renewed', 'malaysia'): 1,
#          ('renewed', 'nm'): 1,
#          ('renewed', 'debate'): 1,
#          ('renewed', 'dig'): 1,
#          ('renewed', 'expressway'): 1,
#          ('renewed', 'soils'): 1,
#          ('renewed', 'halls'): 1,
#          ('renewed', 'super'): 1,
#          ('renewed', 'northwest'): 1,
#          ('renewed', 'acquire'): 1,
#          ('renewed', 'girlfriend'): 1,
#          ('renewed', 'camera'): 1,
#          ('renewed', 'territories'): 1,
#          ('renewed', 'ways'): 1,
#          ('renewed', 'winters'): 1,
#          ('renewed', 'prevented'): 1,
#          ('renewed', 'implemented'): 1,
#          ('renewed', 'cherry'): 1,
#          ('renewed', 'baron'): 1,
#          ('renewed', 'endless'): 1,
#          ('renewed', 'rare'): 1,
#          ('renewed', 'fry'): 1,
#          ('renewed', 'quote'): 1,
#          ('renewed', 'banknotes'): 1,
#          ('renewed', 'tourists'): 1,
#          ('renewed', 'prevalence'): 1,
#          ('renewed', 'beaches'): 1,
#          ('renewed', 'restored'): 1,
#          ('renewed', 'ju'): 1,
#          ('renewed', 'introducing'): 1,
#          ('renewed', 'commandments'): 1,
#          ('renewed', 'aims'): 1,
#          ('renewed', 'dignity'): 1,
#          ('renewed', 'vacation'): 1,
#          ('renewed', 'yi'): 1,
#          ('renewed', 'creative'): 1,
#          ('renewed', 'wrote'): 1,
#          ('renewed', 'paperback'): 1,
#          ('renewed', 'imply'): 1,
#          ('renewed', 'humidity'): 1,
#          ('renewed', 'lucas'): 1,
#          ('renewed', 'ea'): 1,
#          ('renewed', 'possessed'): 1,
#          ('renewed', 'justify'): 1,
#          ('renewed', 'tomorrow'): 1,
#          ('renewed', 'backs'): 1,
#          ('renewed', 'cobain'): 1,
#          ('renewed', 'onwards'): 1,
#          ('renewed', 'outputs'): 1,
#          ('renewed', 'equipment'): 1,
#          ('renewed', 'diffraction'): 1,
#          ('renewed', 'sitcom'): 1,
#          ('renewed', 'birmingham'): 1,
#          ('renewed', 'pearson'): 1,
#          ('renewed', 'credited'): 1,
#          ('renewed', 'draw'): 1,
#          ('renewed', 'click'): 1,
#          ('renewed', 'compound'): 1,
#          ('renewed', 'regions'): 1,
#          ('renewed', 'traveling'): 1,
#          ('renewed', 'stairs'): 1,
#          ('renewed', 'boyle'): 1,
#          ('renewed', 'windows'): 1,
#          ('renewed', 'little'): 1,
#          ('renewed', 'middlesex'): 1,
#          ('renewed', 'team'): 1,
#          ('renewed', 'reaction'): 1,
#          ('renewed', 'vegas'): 1,
#          ('renewed', 'fully'): 1,
#          ('renewed', 'imagine'): 1,
#          ('renewed', 'lyon'): 1,
#          ('renewed', 'spectral'): 1,
#          ('renewed', 'dealing'): 1,
#          ('renewed', 'region'): 1,
#          ('renewed', 'elk'): 1,
#          ('renewed', 'generations'): 1,
#          ('renewed', 'hank'): 1,
#          ('renewed', 'jpeg'): 1,
#          ('renewed', 'spartan'): 1,
#          ('renewed', 'luxembourg'): 1,
#          ('renewed', 'medal'): 1,
#          ('renewed', 'pdf'): 1,
#          ('renewed', 'hall'): 1,
#          ('renewed', 'preface'): 1,
#          ('renewed', 'edges'): 1,
#          ('renewed', 'shipbuilding'): 1,
#          ('renewed', 'housed'): 1,
#          ('renewed', 'bench'): 1,
#          ('renewed', 'breathing'): 1,
#          ('renewed', 'blockade'): 1,
#          ('renewed', 'affects'): 1,
#          ('renewed', 'part'): 1,
#          ('renewed', 'barcelona'): 1,
#          ('renewed', 'sang'): 1,
#          ('renewed', 'argentina'): 1,
#          ('renewed', 'bavaria'): 1,
#          ('renewed', 'testament'): 1,
#          ('renewed', 'believe'): 1,
#          ('renewed', 'designer'): 1,
#          ('renewed', 'legitimacy'): 1,
#          ('renewed', 'seem'): 1,
#          ('renewed', 'kr'): 1,
#          ('renewed', 'cave'): 1,
#          ('renewed', 'sounding'): 1,
#          ('renewed', 'controlling'): 1,
#          ('renewed', 'nouns'): 1,
#          ('renewed', 'golden'): 1,
#          ('renewed', 'dispersed'): 1,
#          ('renewed', 'credibility'): 1,
#          ('renewed', 'echo'): 1,
#          ('renewed', 'emphasizes'): 1,
#          ('renewed', 'skills'): 1,
#          ('renewed', 'pins'): 1,
#          ('renewed', 'installations'): 1,
#          ('renewed', 'commodore'): 1,
#          ('renewed', 'infrogmation'): 1,
#          ('renewed', 'died'): 1,
#          ('renewed', 'prague'): 1,
#          ('renewed', 'photon'): 1,
#          ('renewed', 'volcanoes'): 1,
#          ('renewed', 'volleyball'): 1,
#          ('renewed', 'joy'): 1,
#          ('renewed', 'sympathetic'): 1,
#          ('renewed', 'donovan'): 1,
#          ('renewed', 'bacterial'): 1,
#          ('renewed', 'brothers'): 1,
#          ('renewed', 'fibre'): 1,
#          ('renewed', 'vhs'): 1,
#          ('renewed', 'intermediate'): 1,
#          ('renewed', 'approval'): 1,
#          ('renewed', 'crucial'): 1,
#          ('renewed', 'counties'): 1,
#          ('renewed', 'commonly'): 1,
#          ('renewed', 'bonds'): 1,
#          ('renewed', 'honours'): 1,
#          ('renewed', 'forced'): 1,
#          ('renewed', 'ducks'): 1,
#          ('renewed', 'blows'): 1,
#          ('renewed', 'sleep'): 1,
#          ('renewed', 'maximum'): 1,
#          ('renewed', 'gundam'): 1,
#          ('renewed', 'papacy'): 1,
#          ('renewed', 'winter'): 1,
#          ('renewed', 'articles'): 1,
#          ('renewed', 'gain'): 1,
#          ('renewed', 'operates'): 1,
#          ('renewed', 'comeback'): 1,
#          ('renewed', 'censorship'): 1,
#          ('renewed', 'rulers'): 1,
#          ('renewed', 'tired'): 1,
#          ('renewed', 'cascade'): 1,
#          ('renewed', 'predictions'): 1,
#          ('renewed', 'discovers'): 1,
#          ('renewed', 'across'): 1,
#          ('renewed', 'calcutta'): 1,
#          ('renewed', 'dropped'): 1,
#          ('renewed', 'growth'): 1,
#          ('renewed', 'historia'): 1,
#          ('renewed', 'publishes'): 1,
#          ('renewed', 'contradictory'): 1,
#          ('renewed', 'drums'): 1,
#          ('renewed', 'producer'): 1,
#          ('renewed', 'susceptible'): 1,
#          ('renewed', 'deposit'): 1,
#          ('renewed', 'epic'): 1,
#          ('renewed', 'cosmos'): 1,
#          ('renewed', 'declared'): 1,
#          ('renewed', 'replied'): 1,
#          ('renewed', 'patriot'): 1,
#          ('renewed', 'shut'): 1,
#          ('renewed', 'quo'): 1,
#          ('renewed', 'warming'): 1,
#          ('renewed', 'prophet'): 1,
#          ('renewed', 'elephants'): 1,
#          ('renewed', 'dissolved'): 1,
#          ('renewed', 'toward'): 1,
#          ('renewed', 'presentation'): 1,
#          ('renewed', 'sir'): 1,
#          ('renewed', 'child'): 1,
#          ('renewed', 'artery'): 1,
#          ('renewed', 'technologies'): 1,
#          ('renewed', 'practically'): 1,
#          ('renewed', 'wikiproject'): 1,
#          ...})

# %%
# Count Np(wi,wj)
start = time.time()
for i in range(len(text_t)-5):
    window = text_t[i:i+6]
    window_pairs = list(itertools.permutations(window, 2))
    for pair in window_pairs:
        c_pairs[pair] += 1
end = time.time()
print("time elapsed: " + str(end-start))
# Out:
# time elapsed: 0.009650230407714844

# %%
c_pairs[(vocab[1209],vocab[11])]
# Out:
# 1

# %%
# Count N(Sp)
Sp = [pair for pair in pairs if c_pairs[pair] > 1]
num_Sp = len(Sp)

# %%
num_Sp
# Out:
# 4572

# %%
from scipy.sparse import csr_matrix
from scipy.sparse import lil_matrix
M = lil_matrix((len(vocab), len(vocab)), dtype=np.int8)

# %%
M.shape
# Out:
# (13201, 13201)

# %%
# Count Np(wi,wj)
start = time.time()
for i in range(len(text_t)-5):
    window = text_t[i:i+6]
    window_pairs = list(itertools.permutations(window, 2))
    for pair in window_pairs:
        M[index[pair[0]], index[pair[1]]] += 1
end = time.time()
print("time elapsed: " + str(end-start))
# Out:
# time elapsed: 0.13599681854248047

# %%
M = M.tocsr()

# %%
M.count_nonzero()
# Out:
# 4584

# %%
nonzero = M.nonzero()

# %%
nonzero
# Out:
# (array([   11,    11,    11, ..., 13189, 13189, 13189], dtype=int32),
#  array([ 1209,  1732,  2287, ...,  6473, 12685, 13038], dtype=int32))

# %%
M[11,1209]
# Out:
# 5

# %%
M[1209,11]
# Out:
# 5

# %%
N_w = M.sum(axis = 1)

# %%
N_w[11]
# Out:
# matrix([[60]], dtype=int64)
